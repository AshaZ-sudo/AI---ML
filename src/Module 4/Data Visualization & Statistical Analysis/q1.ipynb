# %% [markdown]
# Title: Histogram of a Single Feature <br>
#
# Question 1: Create a histogram for the age feature from a dataset. Interpret what the shape of the histogram tells us about the distribution of the age feature.

# %%
# Write your code from here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset (replace with your actual data source)
# For example purposes, we'll create a sample dataset:
data = pd.DataFrame({'age': [23, 25, 31, 35, 35, 36, 38, 40, 41, 45, 49, 52, 55, 60, 65, 70, 75, 80]})

# Create histogram
plt.figure(figsize=(8, 5))
sns.histplot(data['age'], bins=10, kde=False, color='skyblue', edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Title: Boxplot for a Single Feature <br>
#
# Question 2: Generate a boxplot for the salary feature and identify any outliers.

# %%
# Write your code from here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample dataset (replace with your actual dataset)
data = pd.DataFrame({'salary': [30000, 32000, 34000, 36000, 38000, 40000, 42000, 44000, 
                                46000, 48000, 50000, 52000, 150000]})  # 150000 might be an outlier

# Create boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(x=data['salary'], color='lightgreen')
plt.title('Boxplot of Salary')
plt.xlabel('Salary')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# Title: Violin Plot of a Single Feature <br>
#
# Question 3: Use a violin plot to visualize the distribution of the height feature and comment on its shape.

# %%
# Write your code from here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample dataset (replace with your actual data)
data = pd.DataFrame({'height': [150, 155, 160, 160, 165, 165, 170, 170, 170, 175, 180, 185, 190, 195]})

# Create violin plot
plt.figure(figsize=(6, 5))
sns.violinplot(y=data['height'], color='lightblue')
plt.title('Violin Plot of Height')
plt.ylabel('Height (cm)')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Title: Scatter Plot to Analyze Relationship<br>
#
# Question 4: Create a scatter plot for the weight and height features to determine if there is a trend.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample dataset (replace with your actual data)
data = pd.DataFrame({
    'height': [150, 155, 160, 165, 170, 175, 180, 185, 190],
    'weight': [50, 53, 57, 60, 65, 70, 75, 80, 85]
})

# Create scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x='height', y='weight', data=data, color='teal')
plt.title('Scatter Plot of Weight vs. Height')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.grid(True)
plt.show()

# %% [markdown]
# Title: Correlation Heatmap<br>
#
# Question 5 : Generate a correlation heatmap for a dataset with multiple features (e.g., height ,weight , age ) and explain the correlations observed.

# %%
# Write your code from here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset (replace with your actual data)
data = pd.DataFrame({
    'height': [150, 160, 165, 170, 175, 180, 185],
    'weight': [50, 58, 63, 68, 72, 77, 83],
    'age':    [18, 22, 25, 30, 35, 40, 45]
})

# Compute correlation matrix
correlation_matrix = data.corr()

# Create heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Title: Descriptive Statistical Analysis<br>
#
# Question 6: Calculate the mean, median, standard deviation, skewness, and kurtosis for the
# temperature feature and discuss the results.

# %%
# Write your code from here
import pandas as pd
from scipy.stats import skew, kurtosis

# Sample dataset (replace with your actual temperature data)
data = pd.DataFrame({'temperature': [22, 23, 21, 24, 25, 26, 28, 30, 29, 31, 35, 40]})

# Descriptive statistics
mean_temp = data['temperature'].mean()
median_temp = data['temperature'].median()
std_temp = data['temperature'].std()
skew_temp = skew(data['temperature'])
kurt_temp = kurtosis(data['temperature'])  # Excess kurtosis

# Display results
print(f"Mean: {mean_temp:.2f}")
print(f"Median: {median_temp:.2f}")
print(f"Standard Deviation: {std_temp:.2f}")
print(f"Skewness: {skew_temp:.2f}")
print(f"Kurtosis: {kurt_temp:.2f}")
# Out:
# Mean: 27.83
# Median: 27.00
# Standard Deviation: 5.61
# Skewness: 0.81
# Kurtosis: -0.10

# %% [markdown]
# Title: Covariance and Correlation between Two Features<br>
#
# Question 7: Compute the covariance and correlation between price and demand in a dataset.
# Explain what these metrics indicate.

# %%
import pandas as pd

# Sample dataset (replace with your actual data)
data = pd.DataFrame({
    'price':  [10, 12, 14, 16, 18, 20],
    'demand': [100, 95, 90, 85, 80, 75]
})

# Covariance
cov = data['price'].cov(data['demand'])

# Correlation
corr = data['price'].corr(data['demand'])

# Display results
print(f"Covariance: {cov:.2f}")
print(f"Correlation: {corr:.2f}")
# Out:
# Covariance: -35.00
# Correlation: -1.00

# %% [markdown]
# Title: Pair Plot for Multivariate Analysis<br>
#
# Question 8: Utilize a pair plot on a dataset to explore the relationships and distributions between
# height , weight , and age . What insights can you glean from this visualization?

# %%
# Write your code from here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset (replace with your actual data)
data = pd.DataFrame({
    'height': [150, 160, 165, 170, 175, 180, 185],
    'weight': [50, 58, 63, 68, 72, 77, 83],
    'age':    [18, 22, 25, 30, 35, 40, 45]
})

# Create pair plot
sns.pairplot(data)
plt.suptitle('Pair Plot of Height, Weight, and Age', y=1.02)
plt.show()

# %% [markdown]
# Title: Principal Component Analysis (PCA)<br>
#
# Question 9 : Apply PCA on a dataset with multiple features (e.g., x1 , x2 , x3 , x4 ) and reduce it to two principal components. Visualize the data in the new feature space.

# %%
# Write your code from here
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Sample dataset with 4 features
np.random.seed(42)
data = pd.DataFrame({
    'x1': np.random.normal(0, 1, 100),
    'x2': np.random.normal(5, 2, 100),
    'x3': np.random.normal(-2, 1.5, 100),
    'x4': np.random.normal(3, 1, 100)
})

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Apply PCA to reduce to 2 principal components
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

# Create a DataFrame with the PCA results
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])

# Visualize the PCA result
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', data=pca_df, color='purple')
plt.title('PCA: Projection onto First Two Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %% [markdown]
# Title: Advanced Pair Plot with Hue Parameter<br>
#
# Question 10 : Create a pair plot for height , weight , and age with an added categorical variable gender as the hue to observe different group trends.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
data = pd.DataFrame({
    'height': [160, 165, 170, 175, 180, 160, 167, 172, 178, 183],
    'weight': [55, 60, 65, 70, 75, 50, 58, 62, 68, 73],
    'age':    [25, 28, 30, 35, 40, 22, 26, 29, 33, 38],
    'gender': ['Female', 'Female', 'Female', 'Female', 'Female',
    'Male', 'Male', 'Male', 'Male', 'Male']
})

# Create pair plot with hue
sns.pairplot(data, hue='gender', palette='Set2')
plt.suptitle('Pair Plot of Height, Weight, and Age by Gender', y=1.02)
plt.show()
